# %%
import pandas as pd
import os

# %% [markdown]
# # Problem statement:
#
# ### There is a folder called Mandir Marg in this directory. For your convenience, I am also providing the google drive link to download it: http://bit.ly/2PY2sox
#
# ### What you have to do is combine all the data from this folder in a single dataframe. Each csv file has a file with a single column called 'value'. Make a new dataframe which holds these 'values' in a separate columns. Each column should be indexed by the name of unique entry it stores like 'BEN', 'CO', 'NOX' etc.

# %% [markdown]
# # Solution

# %%
os.chdir('Mandir Marg')

# %%
lis = os.listdir()
lis
# Out:
# ['Mandir Marg_BEN.csv',
#  'Mandir Marg_CO.csv',
#  'Mandir Marg_NH3.csv',
#  'Mandir Marg_NO1.csv',
#  'Mandir Marg_NO2.csv',
#  'Mandir Marg_NOX.csv',
#  'Mandir Marg_O3.csv',
#  'Mandir Marg_pXy.csv',
#  'Mandir Marg_SO2.csv',
#  'Mandir Marg_Tol.csv']

# %%
# function to find index of '_'
lis[0].index('_')
# Out:
# 11

# %%
# so if we want to extract 'BEN' from the first filename:
lis[0][12:-4]
# Out:
# 'BEN'

# %%
# let's see how to iterate
for filename in lis:
    print(filename)
# Out:
# Mandir Marg_BEN.csv
# Mandir Marg_CO.csv
# Mandir Marg_NH3.csv
# Mandir Marg_NO1.csv
# Mandir Marg_NO2.csv
# Mandir Marg_NOX.csv
# Mandir Marg_O3.csv
# Mandir Marg_pXy.csv
# Mandir Marg_SO2.csv
# Mandir Marg_Tol.csv

# %%
# now let's try to extract the column names
cols = []

for filename in lis:
    cols.append(filename[12:-4])
    
cols
# Out:
# ['BEN', 'CO', 'NH3', 'NO1', 'NO2', 'NOX', 'O3', 'pXy', 'SO2', 'Tol']

# %%
# the function 'zip' lets you iterate over multiple lists at once

# test zip
for colname,dirname in zip(cols,lis):
    print(colname,dirname)
# Out:
# BEN Mandir Marg_BEN.csv
# CO Mandir Marg_CO.csv
# NH3 Mandir Marg_NH3.csv
# NO1 Mandir Marg_NO1.csv
# NO2 Mandir Marg_NO2.csv
# NOX Mandir Marg_NOX.csv
# O3 Mandir Marg_O3.csv
# pXy Mandir Marg_pXy.csv
# SO2 Mandir Marg_SO2.csv
# Tol Mandir Marg_Tol.csv

# %%
# Alright, we are ready now. Let's write some code

answer = pd.DataFrame(columns = cols)

for colname,dirname in zip(cols,lis):
    df = pd.read_csv(dirname)
    answer[colname] = df['value']

# Let's see the final answer: 
answer
# Out:
#        BEN   CO   NH3    NO1   NO2    NOX    O3  pXy  SO2   Tol
# 0      4.8  2.1  31.3   39.0  41.3   93.0   3.9  5.7  2.0  13.8
# 1      4.6  2.1  31.9   34.2  47.0   91.3   4.5  5.2  1.4  10.5
# 2      4.7  2.1  31.9   39.7  47.9  100.0   3.6  5.2  0.6  10.2
# 26582  0.4  NaN   NaN    NaN   NaN    NaN   NaN  1.6  NaN   7.4
# 26583  0.2  NaN   NaN    NaN   NaN    NaN   NaN  0.7  NaN   5.0
# 26584  0.5  NaN   NaN    NaN   NaN    NaN   NaN  0.3  NaN   3.8
# 26585  0.9  NaN   NaN    NaN   NaN    NaN   NaN  0.2  NaN   3.6
# 26586  0.3  NaN   NaN    NaN   NaN    NaN   NaN  3.3  NaN   8.3
# 26587  0.4  NaN   NaN    NaN   NaN    NaN   NaN  7.0  NaN  10.8
# 26588  0.3  NaN   NaN    NaN   NaN    NaN   NaN  6.5  NaN   9.8
# 26589  0.3  NaN   NaN    NaN   NaN    NaN   NaN  4.1  NaN   9.2
# 26590  0.5  NaN   NaN    NaN   NaN    NaN   NaN  1.4  NaN   5.6
# 26591  0.6  NaN   NaN    NaN   NaN    NaN   NaN  0.6  NaN   4.1
# 26592  0.8  NaN   NaN    NaN   NaN    NaN   NaN  0.3  NaN   4.0
# 26593  0.3  NaN   NaN    NaN   NaN    NaN   NaN  0.3  NaN   4.4
# 26594  0.5  NaN   NaN    NaN   NaN    NaN   NaN  0.5  NaN   6.6
# 26595  0.4  NaN   NaN    NaN   NaN    NaN   NaN  0.4  NaN   6.3
# 26596  0.4  NaN   NaN    NaN   NaN    NaN   NaN  0.4  NaN   7.4
# 26597  0.2  NaN   NaN    NaN   NaN    NaN   NaN  0.4  NaN   9.8
# 26598  0.5  NaN   NaN    NaN   NaN    NaN   NaN  0.3  NaN  10.5
# 26599  0.5  NaN   NaN    NaN   NaN    NaN   NaN  0.3  NaN   9.7
# 26600  0.3  NaN   NaN    NaN   NaN    NaN   NaN  0.2  NaN   6.9
# 26601  0.4  NaN   NaN    NaN   NaN    NaN   NaN  0.2  NaN   6.7
# 26602  0.5  NaN   NaN    NaN   NaN    NaN   NaN  0.5  NaN   8.1
# 26603  0.6  NaN   NaN    NaN   NaN    NaN   NaN  0.9  NaN   9.6
# 26604  1.0  NaN   NaN    NaN   NaN    NaN   NaN  1.7  NaN  12.4
# 26605  1.1  NaN   NaN    NaN   NaN    NaN   NaN  2.6  NaN  12.0
# 26606  1.1  NaN   NaN    NaN   NaN    NaN   NaN  3.1  NaN  12.1
# 26607  1.2  NaN   NaN    NaN   NaN    NaN   NaN  5.3  NaN  14.1
#
# [26608 rows x 10 columns]

# %%
# information about it:
answer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26608 entries, 0 to 26607
# Data columns (total 10 columns):
# BEN    26608 non-null object
# CO     22585 non-null float64
# NH3    25774 non-null float64
# NO1    25792 non-null float64
# NO2    26163 non-null float64
# NOX    26188 non-null float64
# O3     24887 non-null float64
# pXy    26608 non-null float64
# SO2    22456 non-null float64
# Tol    26608 non-null float64
# dtypes: float64(9), object(1)
# memory usage: 2.0+ MB
