# %%
import pandas as pd

# %% [markdown]
# ## Initialization

# %%
df = pd.DataFrame(columns=['column1','column2','column3'])
# empty data frame
df
# Out:
# Empty DataFrame
# Columns: [column1, column2, column3]
# Index: []

# %%
dfFromDict = pd.DataFrame({
    'col1':[1,2,0,2],
    'col2':[3,-1,-3,4],
    'col3':[4,3,2,1]
})
dfFromDict
# Out:
#    col1  col2  col3
# 0     1     3     4
# 1     2    -1     3
# 2     0    -3     2
# 3     2     4     1

# %%
# reading from a stored csv file
df = pd.read_csv('ecommerce_data.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## df.head() gives first 5 values

# %%
# checking a data frame is usually done like this
df.head()
# Out:
#    is_mobile  n_products_viewed  visit_duration  is_returning_visitor  \
# 0          1                  0        0.657510                     0
# 1          1                  1        0.568571                     0
# 2          1                  0        0.042246                     1
# 3          1                  1        1.659793                     1
# 4          0                  1        2.014745                     1
#
#    time_of_day  user_action
# 0            3            0
# 1            2            1
# 2            1            0
# 3            1            2
# 4            1            2

# %% [markdown]
# ## tail gives last 5 values

# %%
df.tail()
# Out:
#      is_mobile  n_products_viewed  visit_duration  is_returning_visitor  \
# 495          1                  3        0.731594                     0
# 496          0                  0        6.368775                     1
# 497          0                  0        0.172853                     1
# 498          1                  0        0.209964                     0
# 499          0                  0        2.616882                     1
#
#      time_of_day  user_action
# 495            0            2
# 496            3            0
# 497            3            0
# 498            3            0
# 499            3            0

# %% [markdown]
# ## Shape gives number of rows and columns respectively in a tuple

# %%
df.shape
# Out:
# (500, 6)

# %% [markdown]
# ## Information about a data frame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
# is_mobile               500 non-null int64
# n_products_viewed       500 non-null int64
# visit_duration          500 non-null float64
# is_returning_visitor    500 non-null int64
# time_of_day             500 non-null int64
# user_action             500 non-null int64
# dtypes: float64(1), int64(5)
# memory usage: 23.5 KB

# %% [markdown]
# ## viewing only columns

# %%
cols = df.columns

# %%
cols
# Out:
# Index(['is_mobile', 'n_products_viewed', 'visit_duration',
#        'is_returning_visitor', 'time_of_day', 'user_action'],
#       dtype='object')

# %% [markdown]
# ## Grabbing a single column
# ### grabbing a single column returns a data structure called 'Series'

# %%
df['user_action']
# Out:
# 0      0
# 1      1
# 2      0
# 3      2
# 4      2
# 5      2
# 6      0
# 7      0
# 8      1
# 9      0
# 10     3
# 11     0
# 12     0
# 13     1
# 14     0
# 15     3
# 16     1
# 17     1
# 18     1
# 19     0
# 20     2
# 21     0
# 22     0
# 23     3
# 24     0
# 25     1
# 26     0
# 27     0
# 28     2
# 29     2
#       ..
# 470    0
# 471    0
# 472    2
# 473    0
# 474    2
# 475    0
# 476    3
# 477    0
# 478    0
# 479    0
# 480    0
# 481    0
# 482    2
# 483    2
# 484    1
# 485    1
# 486    1
# 487    0
# 488    1
# 489    1
# 490    3
# 491    0
# 492    0
# 493    0
# 494    2
# 495    2
# 496    0
# 497    0
# 498    0
# 499    0
# Name: user_action, dtype: int64

# %% [markdown]
# ## Intialization of a series

# %%
ser = pd.Series([1,2,33,4])
ser
# Out:
# 0     1
# 1     2
# 2    33
# 3     4
# dtype: int64

# %% [markdown]
# ## Multiple columns

# %%
df[['user_action','visit_duration']]
# Out:
#      user_action  visit_duration
# 0              0        0.657510
# 1              1        0.568571
# 2              0        0.042246
# 3              2        1.659793
# 4              2        2.014745
# 5              2        0.512447
# 6              0        1.440327
# 7              0        0.035260
# 8              1        1.490764
# 9              0        0.005838
# 10             3        2.046040
# 11             0        0.955889
# 12             0        0.159378
# 13             1        0.769272
# 14             0        0.226271
# 15             3        0.988229
# 16             1        0.160583
# 17             1        0.115030
# 18             1        0.483714
# 19             0        0.182401
# 20             2        0.271693
# 21             0        0.296118
# 22             0        0.996240
# 23             3        1.945357
# 24             0        0.029363
# 25             1        0.087355
# 26             0        1.908166
# 27             0        0.119630
# 28             2        0.100013
# 29             2        0.707463
# ..           ...             ...
# 470            0        0.032371
# 471            0        0.625509
# 472            2        1.829021
# 473            0        1.835421
# 474            2        1.999635
# 475            0        0.779601
# 476            3        1.272727
# 477            0        1.387943
# 478            0        0.143232
# 479            0        0.083886
# 480            0        1.480493
# 481            0        1.026237
# 482            2        0.880461
# 483            2        1.815090
# 484            1        0.351077
# 485            1        0.043366
# 486            1        0.021637
# 487            0        0.182413
# 488            1        1.035583
# 489            1        0.453308
# 490            3        0.978725
# 491            0        0.233267
# 492            0        0.666865
# 493            0        2.037393
# 494            2        1.601178
# 495            2        0.731594
# 496            0        6.368775
# 497            0        0.172853
# 498            0        0.209964
# 499            0        2.616882
#
# [500 rows x 2 columns]

# %%
# delete column
# del keyword

del df['visit_duration']
df
# Out:
#      is_mobile  n_products_viewed  is_returning_visitor  time_of_day  \
# 0            1                  0                     0            3
# 1            1                  1                     0            2
# 2            1                  0                     1            1
# 3            1                  1                     1            1
# 4            0                  1                     1            1
# 5            1                  1                     1            1
# 6            0                  0                     1            1
# 7            1                  0                     0            3
# 8            0                  1                     0            0
# 9            0                  0                     1            3
# 10           0                  4                     1            0
# 11           0                  0                     0            3
# 12           1                  0                     0            0
# 13           1                  2                     0            3
# 14           0                  0                     1            3
# 15           1                  3                     1            2
# 16           1                  2                     0            0
# 17           1                  3                     1            2
# 18           0                  1                     1            1
# 19           0                  0                     0            3
# 20           1                  2                     1            1
# 21           0                  0                     0            0
# 22           1                  0                     0            3
# 23           0                  2                     1            0
# 24           0                  0                     0            2
# 25           0                  1                     1            3
# 26           0                  0                     1            1
# 27           0                  2                     0            3
# 28           1                  3                     0            1
# 29           1                  3                     0            0
# ..         ...                ...                   ...          ...
# 470          0                  0                     0            0
# 471          1                  0                     0            0
# 472          1                  1                     1            2
# 473          1                  0                     0            2
# 474          1                  1                     0            3
# 475          0                  0                     0            0
# 476          1                  2                     1            0
# 477          0                  0                     1            0
# 478          0                  1                     0            2
# 479          0                  0                     1            3
# 480          0                  0                     0            2
# 481          0                  0                     1            0
# 482          1                  2                     0            1
# 483          0                  1                     0            0
# 484          1                  2                     1            3
# 485          0                  3                     0            0
# 486          0                  3                     1            0
# 487          1                  0                     0            3
# 488          0                  1                     1            0
# 489          0                  1                     1            2
# 490          1                  3                     1            1
# 491          1                  0                     1            3
# 492          0                  0                     1            2
# 493          0                  0                     0            2
# 494          1                  1                     1            1
# 495          1                  3                     0            0
# 496          0                  0                     1            3
# 497          0                  0                     1            3
# 498          1                  0                     0            3
# 499          0                  0                     1            3
#
#      user_action
# 0              0
# 1              1
# 2              0
# 3              2
# 4              2
# 5              2
# 6              0
# 7              0
# 8              1
# 9              0
# 10             3
# 11             0
# 12             0
# 13             1
# 14             0
# 15             3
# 16             1
# 17             1
# 18             1
# 19             0
# 20             2
# 21             0
# 22             0
# 23             3
# 24             0
# 25             1
# 26             0
# 27             0
# 28             2
# 29             2
# ..           ...
# 470            0
# 471            0
# 472            2
# 473            0
# 474            2
# 475            0
# 476            3
# 477            0
# 478            0
# 479            0
# 480            0
# 481            0
# 482            2
# 483            2
# 484            1
# 485            1
# 486            1
# 487            0
# 488            1
# 489            1
# 490            3
# 491            0
# 492            0
# 493            0
# 494            2
# 495            2
# 496            0
# 497            0
# 498            0
# 499            0
#
# [500 rows x 5 columns]

# %%
# returns a df with the dropped column
df.drop(['is_mobile'],axis=1)
# Out:
#      n_products_viewed  is_returning_visitor  time_of_day  user_action
# 0                    0                     0            3            0
# 1                    1                     0            2            1
# 2                    0                     1            1            0
# 3                    1                     1            1            2
# 4                    1                     1            1            2
# 5                    1                     1            1            2
# 6                    0                     1            1            0
# 7                    0                     0            3            0
# 8                    1                     0            0            1
# 9                    0                     1            3            0
# 10                   4                     1            0            3
# 11                   0                     0            3            0
# 12                   0                     0            0            0
# 13                   2                     0            3            1
# 14                   0                     1            3            0
# 15                   3                     1            2            3
# 16                   2                     0            0            1
# 17                   3                     1            2            1
# 18                   1                     1            1            1
# 19                   0                     0            3            0
# 20                   2                     1            1            2
# 21                   0                     0            0            0
# 22                   0                     0            3            0
# 23                   2                     1            0            3
# 24                   0                     0            2            0
# 25                   1                     1            3            1
# 26                   0                     1            1            0
# 27                   2                     0            3            0
# 28                   3                     0            1            2
# 29                   3                     0            0            2
# ..                 ...                   ...          ...          ...
# 470                  0                     0            0            0
# 471                  0                     0            0            0
# 472                  1                     1            2            2
# 473                  0                     0            2            0
# 474                  1                     0            3            2
# 475                  0                     0            0            0
# 476                  2                     1            0            3
# 477                  0                     1            0            0
# 478                  1                     0            2            0
# 479                  0                     1            3            0
# 480                  0                     0            2            0
# 481                  0                     1            0            0
# 482                  2                     0            1            2
# 483                  1                     0            0            2
# 484                  2                     1            3            1
# 485                  3                     0            0            1
# 486                  3                     1            0            1
# 487                  0                     0            3            0
# 488                  1                     1            0            1
# 489                  1                     1            2            1
# 490                  3                     1            1            3
# 491                  0                     1            3            0
# 492                  0                     1            2            0
# 493                  0                     0            2            0
# 494                  1                     1            1            2
# 495                  3                     0            0            2
# 496                  0                     1            3            0
# 497                  0                     1            3            0
# 498                  0                     0            3            0
# 499                  0                     1            3            0
#
# [500 rows x 4 columns]

# %%
# just deletes the column and deosn't return anything
df.drop(['is_mobile'],axis = 1,inplace = True)
df
# Out:
#      n_products_viewed  is_returning_visitor  time_of_day  user_action
# 0                    0                     0            3            0
# 1                    1                     0            2            1
# 2                    0                     1            1            0
# 3                    1                     1            1            2
# 4                    1                     1            1            2
# 5                    1                     1            1            2
# 6                    0                     1            1            0
# 7                    0                     0            3            0
# 8                    1                     0            0            1
# 9                    0                     1            3            0
# 10                   4                     1            0            3
# 11                   0                     0            3            0
# 12                   0                     0            0            0
# 13                   2                     0            3            1
# 14                   0                     1            3            0
# 15                   3                     1            2            3
# 16                   2                     0            0            1
# 17                   3                     1            2            1
# 18                   1                     1            1            1
# 19                   0                     0            3            0
# 20                   2                     1            1            2
# 21                   0                     0            0            0
# 22                   0                     0            3            0
# 23                   2                     1            0            3
# 24                   0                     0            2            0
# 25                   1                     1            3            1
# 26                   0                     1            1            0
# 27                   2                     0            3            0
# 28                   3                     0            1            2
# 29                   3                     0            0            2
# ..                 ...                   ...          ...          ...
# 470                  0                     0            0            0
# 471                  0                     0            0            0
# 472                  1                     1            2            2
# 473                  0                     0            2            0
# 474                  1                     0            3            2
# 475                  0                     0            0            0
# 476                  2                     1            0            3
# 477                  0                     1            0            0
# 478                  1                     0            2            0
# 479                  0                     1            3            0
# 480                  0                     0            2            0
# 481                  0                     1            0            0
# 482                  2                     0            1            2
# 483                  1                     0            0            2
# 484                  2                     1            3            1
# 485                  3                     0            0            1
# 486                  3                     1            0            1
# 487                  0                     0            3            0
# 488                  1                     1            0            1
# 489                  1                     1            2            1
# 490                  3                     1            1            3
# 491                  0                     1            3            0
# 492                  0                     1            2            0
# 493                  0                     0            2            0
# 494                  1                     1            1            2
# 495                  3                     0            0            2
# 496                  0                     1            3            0
# 497                  0                     1            3            0
# 498                  0                     0            3            0
# 499                  0                     1            3            0
#
# [500 rows x 4 columns]

# %%
# let's reload the data frame before continuing
df = pd.read_csv('ecommerce_data.csv')
df.head()
# Out:
#    is_mobile  n_products_viewed  visit_duration  is_returning_visitor  \
# 0          1                  0        0.657510                     0
# 1          1                  1        0.568571                     0
# 2          1                  0        0.042246                     1
# 3          1                  1        1.659793                     1
# 4          0                  1        2.014745                     1
#
#    time_of_day  user_action
# 0            3            0
# 1            2            1
# 2            1            0
# 3            1            2
# 4            1            2

# %%
# indexing - loc and iloc

# %% [markdown]
# ## loc - [ row index name/names, column name/names]

# %%
df.loc[0,'visit_duration']
# Out:
# 0.657509946224

# %% [markdown]
# ## iloc - [row indexing, column indexing]
#
# ### iloc is numerical indexing, analogous to numpy

# %%
# returns first row with 3rd to 5th column values
df.iloc[0,2:5]
# Out:
# visit_duration          0.65751
# is_returning_visitor    0.00000
# time_of_day             3.00000
# Name: 0, dtype: float64

# %%
#fetching multiple rows
df.iloc[1:4,2:6]
# Out:
#    visit_duration  is_returning_visitor  time_of_day  user_action
# 1        0.568571                     0            2            1
# 2        0.042246                     1            1            0
# 3        1.659793                     1            1            2

# %% [markdown]
# ## Mean of a column - grab a column and call the function mean() on it

# %%
vd_mean = df['visit_duration'].mean()
vd_mean
# Out:
# 1.0558801804438473

# %% [markdown]
# ## Filtering - .loc[condition,column name/names]

# %%
# gives the entries where visit duration is greater than 1.05588 (the mean)
df.loc[df['visit_duration'] > vd_mean, : ]
# Out:
#      is_mobile  n_products_viewed  visit_duration  is_returning_visitor  \
#
# 458            2            0
# 459            1            0
# 461            1            0
# 472            2            2
# 473            2            0
# 474            3            2
# 476            0            3
# 477            0            0
# 480            2            0
# 483            0            2
# 493            2            0
# 494            1            2
# 496            3            0
# 499            3            0
#
# [199 rows x 6 columns]

# %% [markdown]
# ## Group statistics

# %%
gr = df.groupby('is_mobile')
gr

# %%
gr['visit_duration'].mean()
# Out:
# is_mobile
# 0    1.027429
# 1    1.085971
# Name: visit_duration, dtype: float64

# %% [markdown]
# ## More examples

# %%
gr2 = df.groupby('time_of_day')

# %%
gr2['visit_duration'].mean()
# Out:
# time_of_day
# 0    0.977573
# 1    1.047083
# 2    1.121844
# 3    1.066788
# Name: visit_duration, dtype: float64

# %%
# multiple group stats

gr2.mean()
# Out:
#              is_mobile  n_products_viewed  visit_duration  \
# time_of_day
# 0             0.371681           0.929204        0.977573
# 1             0.541667           0.775000        1.047083
# 2             0.527559           0.866142        1.121844
# 3             0.492857           0.850000        1.066788
#
#              is_returning_visitor  user_action
# time_of_day
# 0                        0.460177     0.893805
# 1                        0.633333     0.783333
# 2                        0.456693     0.740157
# 3                        0.521429     0.607143

# %%
gr_multiple = df.groupby(['is_mobile','n_products_viewed'])

# %%
gr_stat = gr_multiple[['is_returning_visitor','visit_duration']].mean()

# %%
gr_stat
# Out:
#                              is_returning_visitor  visit_duration
# is_mobile n_products_viewed
# 0         0                              0.534351        1.141734
#           1                              0.630137        0.954049
#           2                              0.393939        0.740841
#           3                              0.416667        0.964558
#           4                              0.375000        1.101740
# 1         0                              0.495413        1.066629
#           1                              0.537500        1.154722
#           2                              0.379310        1.048518
#           3                              0.611111        1.132842
#           4                              0.428571        0.636068

# %%
gr_stat = gr_stat.reset_index()
gr_stat
# Out:
#    is_mobile  n_products_viewed  is_returning_visitor  visit_duration
# 0          0                  0              0.534351        1.141734
# 1          0                  1              0.630137        0.954049
# 2          0                  2              0.393939        0.740841
# 3          0                  3              0.416667        0.964558
# 4          0                  4              0.375000        1.101740
# 5          1                  0              0.495413        1.066629
# 6          1                  1              0.537500        1.154722
# 7          1                  2              0.379310        1.048518
# 8          1                  3              0.611111        1.132842
# 9          1                  4              0.428571        0.636068

# %% [markdown]
# ## Saving files after analysis

# %%
df.to_csv('group_stats.csv')

# %%
# saving without index
df.to_csv('group_stats.csv',index = False)

# %%
import os
os.chdir('Mandir Marg')

# %%
os.listdir()
# Out:
# ['Mandir Marg_BEN.csv',
#  'Mandir Marg_CO.csv',
#  'Mandir Marg_NH3.csv',
#  'Mandir Marg_NO1.csv',
#  'Mandir Marg_NO2.csv',
#  'Mandir Marg_NOX.csv',
#  'Mandir Marg_O3.csv',
#  'Mandir Marg_pXy.csv',
#  'Mandir Marg_SO2.csv',
#  'Mandir Marg_Tol.csv']

# %%
# temp = "Mandir Marg_" + something + ".csv"

# %%
df1 = pd.read_csv('Mandir Marg_BEN.csv')
df1.head()
# Out:
#   value
# 0   4.8
# 1   4.6
# 2   4.7
# 3   4.6
# 4   4.6

# %%
df2 = pd.read_csv('Mandir Marg_CO.csv')
df2.head()
# Out:
#    value
# 0    2.1
# 1    2.1
# 2    2.1
# 3    1.4
# 4    1.4

# %%
new_df = pd.DataFrame(columns = ['BEN','CO'])
new_df
# Out:
# Empty DataFrame
# Columns: [BEN, CO]
# Index: []

# %%
new_df['BEN'] = df1['value']
new_df['CO'] = df2['value']

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26608 entries, 0 to 26607
# Data columns (total 2 columns):
# BEN    26608 non-null object
# CO     22585 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 415.8+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
# is_mobile               500 non-null int64
# n_products_viewed       500 non-null int64
# visit_duration          500 non-null float64
# is_returning_visitor    500 non-null int64
# time_of_day             500 non-null int64
# user_action             500 non-null int64
# dtypes: float64(1), int64(5)
# memory usage: 23.5 KB

# %%
df1.count()
# Out:
# value    26608
# dtype: int64

# %%
df2.count()
# Out:
# value    22585
# dtype: int64

# %%
df1.count() + df2.count()
# Out:
# value    49193
# dtype: int64

# %%
concat_df = pd.concat([df1.loc[:9,:],df2.loc[:9,:]])
concat_df.count()
# Out:
# value    20
# dtype: int64

# %%
df1.loc[:9,:]
# Out:
#   value
# 0   4.8
# 1   4.6
# 2   4.7
# 3   4.6
# 4   4.6
# 5   4.3
# 6   4.6
# 7   5.1
# 8   4.9
# 9   5.1

# %%
df2.loc[:9,:]
# Out:
#    value
# 0    2.1
# 1    2.1
# 2    2.1
# 3    1.4
# 4    1.4
# 5    3.3
# 6    2.3
# 7    2.9
# 8    2.4
# 9    2.5

# %%
# notice the index. It has repeated values
concat_df
# Out:
#   value
# 0   4.8
# 1   4.6
# 2   4.7
# 3   4.6
# 4   4.6
# 5   4.3
# 6   4.6
# 7   5.1
# 8   4.9
# 9   5.1
# 0   2.1
# 1   2.1
# 2   2.1
# 3   1.4
# 4   1.4
# 5   3.3
# 6   2.3
# 7   2.9
# 8   2.4
# 9   2.5

# %%
# correcting the index
concat_df.reset_index().drop(['index'],axis = 1)
# Out:
#    value
# 0    4.8
# 1    4.6
# 2    4.7
# 3    4.6
# 4    4.6
# 5    4.3
# 6    4.6
# 7    5.1
# 8    4.9
# 9    5.1
# 10   2.1
# 11   2.1
# 12   2.1
# 13   1.4
# 14   1.4
# 15   3.3
# 16   2.3
# 17   2.9
# 18   2.4
# 19   2.5

# %%
# let's get back to a dataframe with multiple columns
os.chdir(r'C:\Users\adity\Desktop\VS-Data Science-and-Machine-Learning\Data Science core\pandas')
df = pd.read_csv('ecommerce_data.csv')
df.head()
# Out:
#    is_mobile  n_products_viewed  visit_duration  is_returning_visitor  \
# 0          1                  0        0.657510                     0
# 1          1                  1        0.568571                     0
# 2          1                  0        0.042246                     1
# 3          1                  1        1.659793                     1
# 4          0                  1        2.014745                     1
#
#    time_of_day  user_action
# 0            3            0
# 1            2            1
# 2            1            0
# 3            1            2
# 4            1            2

# %%
# filtering data frames
df[df['is_mobile'] == 0]
# Out:
#      is_mobile  n_products_viewed  visit_duration  is_returning_visitor  \
#
_mobile  n_products_viewed  visit_duration  is_returning_visitor  \
# 495          1                  3        0.731594                     0
# 496          0                  0        6.368775                     1
# 497          0                  0        0.172853                     1
# 498          1                  0        0.209964                     0
# 499          0                  0        2.616882                     1
#
#      time_of_day  user_action
# 495            0            2
# 496            3            0
# 497            3            0
# 498            3            0
# 499            3            0

# %%
df.loc['indexOfYourChoice'] = to_app_lis

# %%
df.drop([498],inplace = True)

# %%
# 498 is dropped and indexOfYourChoice is added
df.tail()
# Out:
#                    is_mobile  n_products_viewed  visit_duration  \
# 495                      1.0                3.0        0.731594
# 496                      0.0                0.0        6.368775
# 497                      0.0                0.0        0.172853
# 499                      0.0                0.0        2.616882
# indexOfYourChoice        1.0                0.0        0.980000
#
#                    is_returning_visitor  time_of_day  user_action
# 495                                 0.0          0.0          2.0
# 496                                 1.0          3.0          0.0
# 497                                 1.0          3.0          0.0
# 499                                 1.0          3.0          0.0
# indexOfYourChoice                   1.0          2.0          2.0

# %%
# getting rid of the weird index
df.drop(['indexOfYourChoice'],inplace = True)

# %%
df.tail()
# Out:
#      is_mobile  n_products_viewed  visit_duration  is_returning_visitor  \
# 494        1.0                1.0        1.601178                   1.0
# 495        1.0                3.0        0.731594                   0.0
# 496        0.0                0.0        6.368775                   1.0
# 497        0.0                0.0        0.172853                   1.0
# 499        0.0                0.0        2.616882                   1.0
#
#      time_of_day  user_action
# 494          1.0          2.0
# 495          0.0          2.0
# 496          3.0          0.0
# 497          3.0          0.0
# 499          3.0          0.0

# %%
# adding an index which was non-numerical also converts the type of index to 'Object'
# Removing that index does not revert the type back to int. It has to be done manually
df.index.dtype
# Out:
# dtype('O')

# %%
# to convert it back to numerical type:
df.index = pd.to_numeric(df.index)

# %%
# check the type of index again and it will be int again
df.index.dtype
# Out:
# dtype('int64')

# %%
# copy and deep = True: a problem that I come across a lot
df_copied = df.loc[1:10,:].copy(deep = True)
# If the copy is "deep" then the copied data frame is always allocated new memory. This makes it safe to make changes in it
df_copied
# Out:
#     is_mobile  n_products_viewed  visit_duration  is_returning_visitor  \
# 1         1.0                1.0        0.568571                   0.0
# 2         1.0                0.0        0.042246                   1.0
# 3         1.0                1.0        1.659793                   1.0
# 4         0.0                1.0        2.014745                   1.0
# 5         1.0                1.0        0.512447                   1.0
# 6         0.0                0.0        1.440327                   1.0
# 7         1.0                0.0        0.035260                   0.0
# 8         0.0                1.0        1.490764                   0.0
# 9         0.0                0.0        0.005838                   1.0
# 10        0.0                4.0        2.046040                   1.0
#
#     time_of_day  user_action
# 1           2.0          1.0
# 2           1.0          0.0
# 3           1.0          2.0
# 4           1.0          2.0
# 5           1.0          2.0
# 6           1.0          0.0
# 7           3.0          0.0
# 8           0.0          1.0
# 9           3.0          0.0
# 10          0.0          3.0

# %%
# merging data frames

# initializing data frames
df1 = pd.DataFrame(columns=['id','hobby'])
df2 = pd.DataFrame(columns=['id','name'])

# adding values to df1
df1.loc[0] = ['1','hockey']
df1.loc[1] = ['2','dancing']
df1.loc[2] = ['3','football']
df1.loc[3] = ['5','go-cart']

# adding values to df2
df2.loc[0] = ['1','Javed']
df2.loc[1] = ['2','Ming']
df2.loc[2] = ['3','Rufus']
df2.loc[3] = ['4','Bret']

# %%
df1
# Out:
#   id     hobby
# 0  1    hockey
# 1  2   dancing
# 2  3  football
# 3  5   go-cart

# %%
df2
# Out:
#   id   name
# 0  1  Javed
# 1  2   Ming
# 2  3  Rufus
# 3  4   Bret

# %%
# inner join/merge
merged = pd.merge(df1,df2,how='inner',on='id')
merged
# Out:
#   id     hobby   name
# 0  1    hockey  Javed
# 1  2   dancing   Ming
# 2  3  football  Rufus

# %%
# outer join/merge
merged = pd.merge(df1,df2,how='outer',on='id')
merged
# Out:
#   id     hobby   name
# 0  1    hockey  Javed
# 1  2   dancing   Ming
# 2  3  football  Rufus
# 3  5   go-cart    NaN
# 4  4       NaN   Bret

# %%
# changing the columns
df1.columns = ['user_id','hobby']
df1
# Out:
#   user_id     hobby
# 0       1    hockey
# 1       2   dancing
# 2       3  football
# 3       5   go-cart

# %%
df2
# Out:
#   id   name
# 0  1  Javed
# 1  2   Ming
# 2  3  Rufus
# 3  4   Bret

# %%
# merging when column names are different
merged = pd.merge(df1,df2,how='inner',left_on='user_id',right_on='id')
merged.drop(['id'],axis = 1,inplace = True)
merged
# Out:
#   user_id     hobby   name
# 0       1    hockey  Javed
# 1       2   dancing   Ming
# 2       3  football  Rufus

# %% [markdown]
# ## NaN or nan or NAN means "not a number" and implies empty value

# %%
import numpy as np

# %%
np.nan == True
# Out:
# False

# %%
np.nan == False
# Out:
# False

# %%
np.nan > 2
# Out:
# False

# %%
np.nan < 2
# Out:
# False

# %%
np.nan == np.nan
# Out:
# False

# %%
# for checking data in data frames, use this function to check for missing values
pd.isnull(np.nan)
# Out:
# True

# %%
# let's reinitialize df1 and df2
df1 = pd.DataFrame(columns=['id','hobby'])
df2 = pd.DataFrame(columns=['id','name'])

df1.loc[0] = ['1','hockey']
df1.loc[1] = ['2','dancing']
df1.loc[2] = ['3','football']
df1.loc[3] = ['5','go-cart']

df2.loc[0] = ['1','Javed']
df2.loc[1] = ['2','Ming']
df2.loc[2] = ['3','Rufus']
df2.loc[3] = ['4','Bret']

# outer join gives null values
merged = pd.merge(df1,df2,how='outer',on='id')
merged
# Out:
#   id     hobby   name
# 0  1    hockey  Javed
# 1  2   dancing   Ming
# 2  3  football  Rufus
# 3  5   go-cart    NaN
# 4  4       NaN   Bret

# %%
# let's fill the nan of column 'hobby' with something
merged['hobby'].fillna('grrrr',inplace = True)

# %%
merged
# Out:
#   id     hobby   name
# 0  1    hockey  Javed
# 1  2   dancing   Ming
# 2  3  football  Rufus
# 3  5   go-cart    NaN
# 4  4     grrrr   Bret

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 3 columns):
# id       5 non-null object
# hobby    5 non-null object
# name     4 non-null object
# dtypes: object(3)
# memory usage: 160.0+ bytes

# %%
# dropping nan values
merged.dropna(inplace = True) # drops all columns with nan
merged
# Out:
#   id     hobby   name
# 0  1    hockey  Javed
# 1  2   dancing   Ming
# 2  3  football  Rufus
# 4  4     grrrr   Bret
